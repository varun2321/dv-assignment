# %% [markdown]
# <a href="https://colab.research.google.com/github/varun2321/dv-assignment/blob/main/Health_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load weather data from a CSV file
health_data = pd.read_csv('/content/sample_data/Life_Expectancy_Data.csv')

# Visualize precipitation distribution
plt.hist(health_data['Life expectancy '], bins=30, edgecolor='k')
plt.xlabel('Life expectancy ')
plt.ylabel('Year')
plt.show()
